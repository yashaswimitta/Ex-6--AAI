# %%
import nltk
from nltk.corpus import wordnet

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return synonyms

# %%
def process_text_file(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    return text  # Return the processed text

text = process_text_file('samplefile.txt')

# %%
# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

for sentence in sentences:
    # Tokenize each sentence into words
    words = nltk.word_tokenize(sentence)

    # Perform part-of-speech tagging
    pos_tags = nltk.pos_tag(words)

    # Extract verbs
    verbs = [word for word, pos in pos_tags if pos.startswith('V')]

    # Get synonyms for each verb
    for verb in verbs:
        synonyms = get_synonyms(verb)
        print(f"Verb: {verb}")
        print(f"Synonyms: {', '.join(synonyms)}\n")
# Out:
# Verb: chased
# Synonyms: tail, track, trail, pursued, chase_after, go_after, give_chase, chased, chamfer, dog, tag, chase, furrow
#
# Verb: enjoys
# Synonyms: revel, bask, love, savour, savor, delight, enjoy, relish
#
# Verb: baking
# Synonyms: baking, bake, baking_hot, broil
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: transforming
# Synonyms: transmute, transubstantiate, metamorphose, transform, translate
#
# Verb: played
# Synonyms: play, represent, trifle, playact, recreate, diddle, bring, spiel, dally, bet, make_for, act, flirt, meet, fiddle, take_on, work, wager, run, act_as, played, roleplay, encounter, toy, wreak
#
# Verb: explores
# Synonyms: search, explore, research
#
# Verb: was
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, Washington, WA, Evergreen_State, comprise, live
#
# Verb: decided
# Synonyms: distinct, decided, settle, make_up_one's_mind, adjudicate, resolve, decide, determine
#
# Verb: learn
# Synonyms: study, larn, learn, hear, instruct, find_out, get_word, read, pick_up, acquire, watch, discover, see, con, teach, determine, get_a_line, memorise, ascertain, take, get_wind, check, memorize
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: striving
# Synonyms: strain, endeavour, pains, nisus, endeavor, strive, reach, striving
#
# Verb: find
# Synonyms: witness, find_out, retrieve, get, discovery, find, regain, detect, breakthrough, find_oneself, feel, get_hold, obtain, incur, discover, happen, recover, see, observe, determine, encounter, receive, chance, line_up, come_up, rule, ascertain, bump, notice, uncovering
#
# Verb: brewed
# Synonyms: brew
#
# Verb: filled
# Synonyms: fulfil, fulfill, replete, fill_up, satisfy, sate, occupy, filled, take, fill, meet, make_full, satiate
#
# Verb: Recycling
# Synonyms: recycle, reuse, recycling, reprocess
#
# Verb: helps
# Synonyms: facilitate, assistance, assist, helper, service, supporter, help, aid, serve, avail, help_oneself, assistant
#
# Verb: conserve
# Synonyms: husband, economize, maintain, keep_up, economise, preserve, conserve, preserves, conserves
#
# Verb: stood
# Synonyms: put_up, support, bear, stand_up, brook, suffer, abide, endure, stand, digest, stick_out, resist, remain_firm, fend, stomach, place_upright, tolerate
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: waiting
# Synonyms: await, ready_and_waiting, expect, waiting, hold_off, wait, look, waitress, hold_back
#
# Verb: be
# Synonyms: be, equal, represent, embody, constitute, beryllium, make_up, personify, follow, exist, cost, atomic_number_4, Be, comprise, live, glucinium
#
# Verb: explored
# Synonyms: search, explore, research
#
# Verb: Taking
# Synonyms: need, direct, study, take_away, learn, make, exact, have, take_aim, necessitate, hold, charter, occupy, bring, take_up, contract, claim, postulate, require, subscribe, pack, get, winning, pickings, consider, taking, accept, aim, engage, use_up, read, guide, take_in, withdraw, strike, contain, select, rent, remove, ask, take_on, train, acquire, carry, involve, drive, film, pick_out, ingest, consume, demand, shoot, submit, call_for, convey, choose, lead, adopt, deal, conduct, look_at, admit, subscribe_to, take, lease, hire, get_hold_of, fill, fetching, assume
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: relax
# Synonyms: relax, unstrain, slack_up, unwind, loosen, loose, slow_down, slacken, unlax, decompress, unbend, make_relaxed, slack, loosen_up
#
# Verb: enjoy
# Synonyms: revel, bask, love, savour, savor, delight, enjoy, relish
#
# Verb: traveling
# Synonyms: move, locomote, trip, traveling, jaunt, move_around, go, travelling, journey, travel
#
# Verb: has
# Synonyms: possess, have_got, make, stimulate, have, hold, give_birth, throw, give, get, accept, bear, deliver, HA, let, birth, sustain, ingest, own, consume, feature, induce, cause, receive, hour_angle, experience, suffer, take, take_in
#
# Verb: made
# Synonyms: piss, puddle, stimulate, make, made, progress_to, have, name, pull_in, attain, hold, ca-ca, crap, pee, pass_water, throw, realise, give, stool, get, build, gain, cook, make_believe, piddle, take_a_crap, score, realize, make_water, get_to, construct, form, take_a_shit, fix, wee, wee-wee, defecate, create, do, work, seduce, make_up, pee-pee, hit, reach, shit, urinate, produce, relieve_oneself, spend_a_penny, earn, induce, cause, establish, lay_down, nominate, ready, prepare, constitute, clear, draw, bring_in, take, pretend, micturate, take_in, take_a_leak, arrive_at
#
# Verb: Learning
# Synonyms: study, learn, larn, hear, instruct, learning, find_out, get_word, read, pick_up, scholarship, eruditeness, erudition, acquire, watch, discover, see, con, encyclopedism, teach, determine, encyclopaedism, get_a_line, memorise, learnedness, ascertain, take, get_wind, check, acquisition, memorize
#
# Verb: play
# Synonyms: play, represent, trifle, gaming, maneuver, playact, recreate, diddle, bring, period_of_play, spiel, caper, swordplay, romp, frolic, dally, fun, bet, looseness, make_for, act, drama, flirt, child's_play, meet, manoeuvre, fiddle, take_on, work, wager, turn, run, bid, gambling, dramatic_play, sport, act_as, roleplay, free_rein, encounter, toy, wreak, gambol, shimmer, playing_period
#
# Verb: be
# Synonyms: be, equal, represent, embody, constitute, beryllium, make_up, personify, follow, exist, cost, atomic_number_4, Be, comprise, live, glucinium
#
# Verb: Protecting
# Synonyms: protecting, protect
#
# Verb: endangered
# Synonyms: menace, threaten, scupper, peril, queer, jeopardise, endanger, endangered, imperil, jeopardize, expose
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: maintaining
# Synonyms: asseverate, maintain, keep_up, wield, defend, sustain, preserve, hold, exert, keep, conserve, uphold, observe, assert
#
# Verb: has
# Synonyms: possess, have_got, make, stimulate, have, hold, give_birth, throw, give, get, accept, bear, deliver, HA, let, birth, sustain, ingest, own, consume, feature, induce, cause, receive, hour_angle, experience, suffer, take, take_in
#
# Verb: revolutionized
# Synonyms: revolutionise, inspire, overturn, revolutionize
#
# Verb: allows
# Synonyms: countenance, appropriate, let, permit, set_aside, admit, earmark, take_into_account, give_up, grant, provide, allow_for, leave, reserve, tolerate, allow
#
# Verb: study
# Synonyms: study, learn, analyse, analyze, canvass, hit_the_books, cogitation, consider, read, meditate, bailiwick, field, work, subject_field, contemplate, subject_area, field_of_study, subject, examine, canvas, written_report, sketch, take, report, survey, discipline
#
# Verb: promotes
# Synonyms: elevate, further, push, promote, upgrade, raise, advertise, advertize, kick_upstairs, advance, boost, encourage
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: maintaining
# Synonyms: asseverate, maintain, keep_up, wield, defend, sustain, preserve, hold, exert, keep, conserve, uphold, observe, assert
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: facing
# Synonyms: lining, confront, front, present, facing, face_up, cladding, look, veneer, face
#
# Verb: are
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, ar, comprise, live, are
#
# Verb: becoming
# Synonyms: suit, decent, turn, seemly, comme_il_faut, becoming, go, comely, decorous, become, get
#
# Verb: allows
# Synonyms: countenance, appropriate, let, permit, set_aside, admit, earmark, take_into_account, give_up, grant, provide, allow_for, leave, reserve, tolerate, allow
#
# Verb: learn
# Synonyms: study, larn, learn, hear, instruct, find_out, get_word, read, pick_up, acquire, watch, discover, see, con, teach, determine, get_a_line, memorise, ascertain, take, get_wind, check, memorize
#
# Verb: Volunteering
# Synonyms: volunteer, offer
#
# Verb: help
# Synonyms: facilitate, assistance, assist, helper, service, supporter, help, aid, serve, avail, help_oneself, assistant
#
# Verb: be
# Synonyms: be, equal, represent, embody, constitute, beryllium, make_up, personify, follow, exist, cost, atomic_number_4, Be, comprise, live, glucinium
#
# Verb: are
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, ar, comprise, live, are
#
# Verb: allows
# Synonyms: countenance, appropriate, let, permit, set_aside, admit, earmark, take_into_account, give_up, grant, provide, allow_for, leave, reserve, tolerate, allow
#
# Verb: create
# Synonyms: create, produce, make
#
# Verb: innovate
# Synonyms: introduce, innovate
#
# Verb: Developing
# Synonyms: development, recrudesce, get, spring_up, underdeveloped, arise, evolve, educate, train, modernise, acquire, uprise, germinate, develop, produce, formulate, make_grow, originate, explicate, prepare, grow, modernize, break, developing, build_up, rise
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: achieving
# Synonyms: attain, accomplish, achieve, reach
#
# Verb: is
# Synonyms: be, equal, represent, embody, constitute, make_up, personify, follow, exist, cost, comprise, live
#
# Verb: unlocking
# Synonyms: unlock
